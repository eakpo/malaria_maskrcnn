# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Root directory of the project
ROOT_DIR = "/content/drive/MyDrive/Colab Notebooks/Mask-R-CNN-using-Tensorflow2"

# %%
import os

# Set the desired directory path
directory_path = "/content/drive/MyDrive/Colab Notebooks/Mask-R-CNN-using-Tensorflow2"

# Change the current working directory to the specified path
os.chdir(directory_path)

# %%
# !python custom.py
# Out:
# 2023-10-25 06:14:03.832145: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-25 06:14:03.832201: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-25 06:14:03.832239: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-25 06:14:03.840616: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
